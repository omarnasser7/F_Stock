# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Define the date range
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

# Download stock data for Tesla (TSLA)
tesla_stock = yf.download('TSLA', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_stock.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
plt.figure(figsize=(12, 6))
plt.plot(tesla_stock['Close'], label='Tesla Close Price')
plt.title('Tesla Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in tesla_stock.columns:
    tesla_stock['Date'] = tesla_stock.index
tesla_stock.set_index('Date', inplace=True)

tesla_prices = tesla_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
tesla_prices_scaled = scaler.fit_transform(tesla_prices)
joblib.dump(scaler, "tesla_scaler.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(tesla_prices_scaled) * 0.8)
train_data = tesla_prices_scaled[:train_size]
test_data = tesla_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0013
# Epoch 1: val_loss improved from inf to 0.00185, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 0.0013 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 2/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5020e-04
# Epoch 2: val_loss did not improve from 0.00185
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 5.4993e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 3/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.0568e-04
# Epoch 3: val_loss improved from 0.00185 to 0.00120, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 4.0544e-04 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 4/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.7192e-04
# Epoch 4: val_loss did not improve from 0.00120
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.7170e-04 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 5/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1438e-04
# Epoch 5: val_loss did not improve from 0.00120
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 2.1442e-04 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 6/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0433e-04
# Epoch 6: val_loss did not improve from 0.00120
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 2.0429e-04 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 7/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7532e-04
# Epoch 7: val_loss improved from 0.00120 to 0.00092, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.7530e-04 - val_loss: 9.2040e-04 - learning_rate: 0.0010
# Epoch 8/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5408e-04
# Epoch 8: val_loss did not improve from 0.00092
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.5412e-04 - val_loss: 9.7004e-04 - learning_rate: 0.0010
# Epoch 9/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5642e-04
# Epoch 9: val_loss improved from 0.00092 to 0.00074, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.5661e-04 - val_loss: 7.3980e-04 - learning_rate: 0.0010
# Epoch 10/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8683e-04
# Epoch 10: val_loss did not improve from 0.00074
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.8673e-04 - val_loss: 9.5336e-04 - learning_rate: 0.0010
# Epoch 11/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9132e-04
# Epoch 11: val_loss improved from 0.00074 to 0.00057, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.9135e-04 - val_loss: 5.6656e-04 - learning_rate: 0.0010
# Epoch 12/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3692e-04
# Epoch 12: val_loss improved from 0.00057 to 0.00050, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.3707e-04 - val_loss: 5.0487e-04 - learning_rate: 0.0010
# Epoch 13/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4744e-04
# Epoch 13: val_loss did not improve from 0.00050
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.4797e-04 - val_loss: 6.0071e-04 - learning_rate: 0.0010
# Epoch 14/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1208e-04
# Epoch 14: val_loss did not improve from 0.00050
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1229e-04 - val_loss: 6.6446e-04 - learning_rate: 0.0010
# Epoch 15/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3616e-04
# Epoch 15: val_loss did not improve from 0.00050
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.3621e-04 - val_loss: 5.9094e-04 - learning_rate: 0.0010
# Epoch 16/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0901e-04
# Epoch 16: val_loss did not improve from 0.00050
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.0904e-04 - val_loss: 7.7647e-04 - learning_rate: 0.0010
# Epoch 17/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.2088e-05
# Epoch 17: val_loss did not improve from 0.00050
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 9.2190e-05 - val_loss: 5.6165e-04 - learning_rate: 5.0000e-04
# Epoch 18/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0122e-04
# Epoch 18: val_loss did not improve from 0.00050
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.0124e-04 - val_loss: 5.8262e-04 - learning_rate: 5.0000e-04
# Epoch 19/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.6489e-05
# Epoch 19: val_loss improved from 0.00050 to 0.00046, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 9.6536e-05 - val_loss: 4.5885e-04 - learning_rate: 5.0000e-04
# Epoch 20/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0466e-04
# Epoch 20: val_loss did not improve from 0.00046
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 1.0461e-04 - val_loss: 5.0590e-04 - learning_rate: 5.0000e-04
# Epoch 21/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0460e-04
# Epoch 21: val_loss improved from 0.00046 to 0.00046, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.0458e-04 - val_loss: 4.5532e-04 - learning_rate: 5.0000e-04
# Epoch 22/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.4963e-05
# Epoch 22: val_loss did not improve from 0.00046
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 9.5241e-05 - val_loss: 4.7181e-04 - learning_rate: 5.0000e-04
# Epoch 23/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.4652e-05
# Epoch 23: val_loss improved from 0.00046 to 0.00045, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 9.4735e-05 - val_loss: 4.5390e-04 - learning_rate: 5.0000e-04
# Epoch 24/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1885e-04
# Epoch 24: val_loss did not improve from 0.00045
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1879e-04 - val_loss: 4.7181e-04 - learning_rate: 5.0000e-04
# Epoch 25/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3366e-05
# Epoch 25: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.3389e-05 - val_loss: 4.8104e-04 - learning_rate: 2.5000e-04
# Epoch 26/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.0844e-05
# Epoch 26: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 9.0832e-05 - val_loss: 5.1811e-04 - learning_rate: 2.5000e-04
# Epoch 27/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0656e-05
# Epoch 27: val_loss improved from 0.00045 to 0.00045, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 9.0629e-05 - val_loss: 4.5053e-04 - learning_rate: 2.5000e-04
# Epoch 28/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8442e-05
# Epoch 28: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 8.8433e-05 - val_loss: 5.2650e-04 - learning_rate: 2.5000e-04
# Epoch 29/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9684e-05
# Epoch 29: val_loss did not improve from 0.00045
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.9750e-05 - val_loss: 7.7082e-04 - learning_rate: 2.5000e-04
# Epoch 30/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1059e-04
# Epoch 30: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.1044e-04 - val_loss: 4.5532e-04 - learning_rate: 1.2500e-04
# Epoch 31/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5849e-05
# Epoch 31: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.5868e-05 - val_loss: 5.8918e-04 - learning_rate: 1.2500e-04
# Epoch 32/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8856e-05
# Epoch 32: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.8832e-05 - val_loss: 5.7114e-04 - learning_rate: 1.2500e-04
# Epoch 33/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.8274e-05
# Epoch 33: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 9.8154e-05 - val_loss: 4.5271e-04 - learning_rate: 1.2500e-04
# Epoch 34/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5731e-05
# Epoch 34: val_loss did not improve from 0.00045
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.5748e-05 - val_loss: 5.2027e-04 - learning_rate: 1.2500e-04
# Epoch 35/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.1000e-05
# Epoch 35: val_loss improved from 0.00045 to 0.00045, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.1070e-05 - val_loss: 4.5045e-04 - learning_rate: 6.2500e-05
# Epoch 36/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3099e-05
# Epoch 36: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.3052e-05 - val_loss: 4.5613e-04 - learning_rate: 6.2500e-05
# Epoch 37/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9772e-05
# Epoch 37: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 6.9822e-05 - val_loss: 4.5374e-04 - learning_rate: 6.2500e-05
# Epoch 38/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5965e-05
# Epoch 38: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.5958e-05 - val_loss: 4.8424e-04 - learning_rate: 6.2500e-05
# Epoch 39/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9737e-05
# Epoch 39: val_loss did not improve from 0.00045
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.9704e-05 - val_loss: 4.9293e-04 - learning_rate: 6.2500e-05
# Epoch 40/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.6952e-05
# Epoch 40: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.6941e-05 - val_loss: 4.6742e-04 - learning_rate: 3.1250e-05
# Epoch 41/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.1613e-05
# Epoch 41: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 6.1687e-05 - val_loss: 4.5181e-04 - learning_rate: 3.1250e-05
# Epoch 42/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0224e-05
# Epoch 42: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.0248e-05 - val_loss: 4.7959e-04 - learning_rate: 3.1250e-05
# Epoch 43/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.1588e-05
# Epoch 43: val_loss improved from 0.00045 to 0.00045, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 6.1622e-05 - val_loss: 4.4816e-04 - learning_rate: 3.1250e-05
# Epoch 44/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.6319e-05
# Epoch 44: val_loss did not improve from 0.00045
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.6297e-05 - val_loss: 4.8180e-04 - learning_rate: 3.1250e-05
# Epoch 45/50
# 356/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.3063e-05
# Epoch 45: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 7.3060e-05 - val_loss: 4.6953e-04 - learning_rate: 1.5625e-05
# Epoch 46/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.3773e-05
# Epoch 46: val_loss improved from 0.00045 to 0.00045, saving model to best_lstm_model.keras
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 7.3767e-05 - val_loss: 4.4784e-04 - learning_rate: 1.5625e-05
# Epoch 47/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8388e-05
# Epoch 47: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.8371e-05 - val_loss: 4.4828e-04 - learning_rate: 1.5625e-05
# Epoch 48/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.3150e-05
# Epoch 48: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 6.3254e-05 - val_loss: 4.5080e-04 - learning_rate: 1.5625e-05
# Epoch 49/50
# 354/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9736e-05
# Epoch 49: val_loss did not improve from 0.00045
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 6.9766e-05 - val_loss: 4.4833e-04 - learning_rate: 1.5625e-05
# Epoch 50/50
# 355/357 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5383e-05
# Epoch 50: val_loss did not improve from 0.00045
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 7.5355e-05 - val_loss: 4.5551e-04 - learning_rate: 7.8125e-06

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(tesla_stock.index[train_size:], tesla_stock['Close'][train_size:], label='Actual Tesla Stock Price')
plt.plot(tesla_stock.index[train_size + seq_length:], predictions, label='Predicted Tesla Stock Price')
plt.title('Tesla Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test, predictions)
# Out:
# RMSE: 229.15748147370024, MAE: 224.05836327538114, R2: -3642491.029097909

# %%
# Fetch data from Yahoo Finance
tesla_stock = yf.download("TSLA", start="2024-01-01", end="2024-11-30")
tesla_stock['Date'] = tesla_stock.index
tesla_prices = tesla_stock['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
tesla_prices_scaled = scaler.transform(tesla_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(tesla_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(tesla_stock['Date'], tesla_stock['Close'], label="Actual Tesla Prices", color='blue')
plt.plot(tesla_stock['Date'][seq_length:], predictions_rescaled, label="Predicted Tesla Prices", color='red')
plt.title("Tesla Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
