# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Define the date range
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

# Download stock data for Tesla (TSLA)
tesla_stock = yf.download('TSLA', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_stock.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
plt.figure(figsize=(12, 6))
plt.plot(tesla_stock['Close'], label='Tesla Close Price')
plt.title('Tesla Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in tesla_stock.columns:
    tesla_stock['Date'] = tesla_stock.index
tesla_stock.set_index('Date', inplace=True)

tesla_prices = tesla_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
tesla_prices_scaled = scaler.fit_transform(tesla_prices)
joblib.dump(scaler, "tesla_scaler_5.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(tesla_prices_scaled) * 0.8)
train_data = tesla_prices_scaled[:train_size]
test_data = tesla_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 5 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 5])

    return np.array(sequences), np.array(labels)

seq_length = 100
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(5))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,005 (125.02 KB)
#  Trainable params: 32,005 (125.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_5.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038
# Epoch 1: val_loss improved from inf to 0.00436, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0038 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.2516e-04
# Epoch 2: val_loss did not improve from 0.00436
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 6.2496e-04 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 3/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 9.4806e-04
# Epoch 3: val_loss improved from 0.00436 to 0.00228, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 9.4569e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 4/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2093e-04
# Epoch 4: val_loss improved from 0.00228 to 0.00218, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 4.2133e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 5/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8554e-04
# Epoch 5: val_loss improved from 0.00218 to 0.00209, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 3.8594e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6059e-04
# Epoch 6: val_loss improved from 0.00209 to 0.00171, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 3.6078e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 7/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.3214e-04
# Epoch 7: val_loss improved from 0.00171 to 0.00155, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 3.3188e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 8/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1823e-04
# Epoch 8: val_loss improved from 0.00155 to 0.00148, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 3.1822e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 9/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.2350e-04
# Epoch 9: val_loss did not improve from 0.00148
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 3.2376e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 10/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5745e-04
# Epoch 10: val_loss improved from 0.00148 to 0.00147, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 2.5753e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 11/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.4403e-04
# Epoch 11: val_loss did not improve from 0.00147
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.4457e-04 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 12/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0335e-04
# Epoch 12: val_loss did not improve from 0.00147
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 3.0319e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3836e-04
# Epoch 13: val_loss improved from 0.00147 to 0.00133, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 2.3836e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-04
# Epoch 14/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4569e-04
# Epoch 14: val_loss did not improve from 0.00133
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.4566e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-04
# Epoch 15/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8587e-04
# Epoch 15: val_loss did not improve from 0.00133
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.8562e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.8310e-04
# Epoch 16: val_loss improved from 0.00133 to 0.00132, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 2.8304e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-04
# Epoch 17/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3853e-04
# Epoch 17: val_loss did not improve from 0.00132
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.3839e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5828e-04
# Epoch 18: val_loss did not improve from 0.00132
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 2.5817e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 19/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1155e-04
# Epoch 19: val_loss did not improve from 0.00132
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 2.1157e-04 - val_loss: 0.0014 - learning_rate: 2.5000e-04
# Epoch 20/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1366e-04
# Epoch 20: val_loss did not improve from 0.00132
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 2.1364e-04 - val_loss: 0.0017 - learning_rate: 2.5000e-04
# Epoch 21/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8585e-04
# Epoch 21: val_loss improved from 0.00132 to 0.00126, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 1.8595e-04 - val_loss: 0.0013 - learning_rate: 2.5000e-04
# Epoch 22/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.3721e-04
# Epoch 22: val_loss improved from 0.00126 to 0.00121, saving model to best_lstm_model_5.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 2.3704e-04 - val_loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2131e-04
# Epoch 23: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.2125e-04 - val_loss: 0.0013 - learning_rate: 2.5000e-04
# Epoch 24/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2278e-04
# Epoch 24: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.2264e-04 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 25/50
# 349/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2158e-04
# Epoch 25: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.2146e-04 - val_loss: 0.0013 - learning_rate: 2.5000e-04
# Epoch 26/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3282e-04
# Epoch 26: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.3266e-04 - val_loss: 0.0013 - learning_rate: 2.5000e-04
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8634e-04
# Epoch 27: val_loss did not improve from 0.00121
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8638e-04 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9574e-04
# Epoch 28: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.9574e-04 - val_loss: 0.0012 - learning_rate: 1.2500e-04
# Epoch 29/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8768e-04
# Epoch 29: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 1.8772e-04 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 30/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7817e-04
# Epoch 30: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 1.7825e-04 - val_loss: 0.0013 - learning_rate: 1.2500e-04
# Epoch 31/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9223e-04
# Epoch 31: val_loss did not improve from 0.00121
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.9225e-04 - val_loss: 0.0012 - learning_rate: 1.2500e-04
# Epoch 32/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8100e-04
# Epoch 32: val_loss did not improve from 0.00121
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.8103e-04 - val_loss: 0.0013 - learning_rate: 1.2500e-04

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()

def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 226.0064482301482, MAE: 221.30907307403064, R2: -4021784.69323513

# %%
# Fetch data from Yahoo Finance
end_date = datetime.now().strftime('%Y-%m-%d')

tesla_stock = yf.download("TSLA", start="2024-01-01", end=end_date)
tesla_stock['Date'] = tesla_stock.index
tesla_prices = tesla_stock['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
tesla_prices_scaled = scaler.transform(tesla_prices)

# Create sequences for prediction
seq_length = 100
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(tesla_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(tesla_stock['Date'], tesla_stock['Close'], label="Actual Tesla Prices", color='blue')
plt.plot(tesla_stock['Date'][seq_length:], predictions_rescaled, label="Predicted Tesla Prices", color='red')
plt.title("Tesla Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
seq_length=100
# Prepare future prediction sequence
X_future = tesla_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024
future_dates = pd.date_range(start="2024-12-14", end="2024-12-22", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
