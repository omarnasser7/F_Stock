# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

aramco_stock = yf.download('2222.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aramco_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker        2222.SR    2222.SR    2222.SR    2222.SR    2222.SR    2222.SR
# Date
# 2019-12-11  24.670721  29.090908  29.090908  29.090908  29.090908   38289394
# 2019-12-12  25.792120  30.413223  31.983471  29.752066  31.983471  505692621
# 2019-12-15  26.212639  30.909090  30.991735  30.413223  30.661158   98349281
# 2019-12-16  26.633163  31.404959  31.487602  30.991735  30.991735  105973907
# 2019-12-17  26.457949  31.198347  31.528925  30.991735  31.446280  142672245

# %%
plt.figure(figsize=(12, 6))
plt.plot(aramco_stock['Close'], label='Aramco Close Price')
plt.title('Aramco Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in aramco_stock.columns:
    aramco_stock['Date'] = aramco_stock.index
aramco_stock.set_index('Date', inplace=True)

aapl_prices = aramco_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "aramco_stock_5.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 5 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 5])

    return np.array(sequences), np.array(labels)

seq_length = 100
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(5))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,005 (125.02 KB)
#  Trainable params: 32,005 (125.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_5.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0481
# Epoch 1: val_loss improved from inf to 0.00199, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0476 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 2/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035
# Epoch 2: val_loss did not improve from 0.00199
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0035 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 3/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029
# Epoch 3: val_loss did not improve from 0.00199
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0029 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 4/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0034
# Epoch 4: val_loss improved from 0.00199 to 0.00175, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0034 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 5/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039
# Epoch 5: val_loss did not improve from 0.00175
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0039 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029
# Epoch 6: val_loss improved from 0.00175 to 0.00097, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0029 - val_loss: 9.6532e-04 - learning_rate: 0.0010
# Epoch 7/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0025
# Epoch 7: val_loss did not improve from 0.00097
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0025 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 8/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026
# Epoch 8: val_loss improved from 0.00097 to 0.00086, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0026 - val_loss: 8.5995e-04 - learning_rate: 0.0010
# Epoch 9/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025
# Epoch 9: val_loss improved from 0.00086 to 0.00081, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0025 - val_loss: 8.1047e-04 - learning_rate: 0.0010
# Epoch 10/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0026
# Epoch 10: val_loss improved from 0.00081 to 0.00070, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0026 - val_loss: 7.0076e-04 - learning_rate: 0.0010
# Epoch 11/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025
# Epoch 11: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0025 - val_loss: 8.6721e-04 - learning_rate: 0.0010
# Epoch 12/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025
# Epoch 12: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 13/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023
# Epoch 13: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0023 - val_loss: 9.2341e-04 - learning_rate: 0.0010
# Epoch 14/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023
# Epoch 14: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0023 - val_loss: 7.1022e-04 - learning_rate: 0.0010
# Epoch 15/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025
# Epoch 15: val_loss did not improve from 0.00070
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0025 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 16/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022
# Epoch 16: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0022 - val_loss: 9.7507e-04 - learning_rate: 5.0000e-04
# Epoch 17/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021
# Epoch 17: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0021 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 18/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022
# Epoch 18: val_loss did not improve from 0.00070
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0022 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 19/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019
# Epoch 19: val_loss improved from 0.00070 to 0.00059, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0019 - val_loss: 5.8885e-04 - learning_rate: 5.0000e-04
# Epoch 20/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.00059
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0019 - val_loss: 6.3272e-04 - learning_rate: 5.0000e-04
# Epoch 21/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0018
# Epoch 21: val_loss did not improve from 0.00059
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0018 - val_loss: 6.2360e-04 - learning_rate: 5.0000e-04
# Epoch 22/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019
# Epoch 22: val_loss did not improve from 0.00059
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0019 - val_loss: 9.9401e-04 - learning_rate: 5.0000e-04
# Epoch 23/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020
# Epoch 23: val_loss did not improve from 0.00059
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0020 - val_loss: 6.2653e-04 - learning_rate: 5.0000e-04
# Epoch 24/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017
# Epoch 24: val_loss did not improve from 0.00059
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0017 - val_loss: 6.1433e-04 - learning_rate: 5.0000e-04
# Epoch 25/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019
# Epoch 25: val_loss improved from 0.00059 to 0.00056, saving model to best_lstm_model_5.keras
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0019 - val_loss: 5.6239e-04 - learning_rate: 2.5000e-04
# Epoch 26/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020
# Epoch 26: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0020 - val_loss: 8.9635e-04 - learning_rate: 2.5000e-04
# Epoch 27/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0017
# Epoch 27: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0017 - val_loss: 0.0010 - learning_rate: 2.5000e-04
# Epoch 28/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0020
# Epoch 28: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0020 - val_loss: 6.2196e-04 - learning_rate: 2.5000e-04
# Epoch 29/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019
# Epoch 29: val_loss did not improve from 0.00056
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0019 - val_loss: 6.0150e-04 - learning_rate: 2.5000e-04
# Epoch 30/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018
# Epoch 30: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0018 - val_loss: 6.4283e-04 - learning_rate: 1.2500e-04
# Epoch 31/50
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0016
# Epoch 31: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0016 - val_loss: 7.0993e-04 - learning_rate: 1.2500e-04
# Epoch 32/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019
# Epoch 32: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0019 - val_loss: 5.8379e-04 - learning_rate: 1.2500e-04
# Epoch 33/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0016
# Epoch 33: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0016 - val_loss: 6.6257e-04 - learning_rate: 1.2500e-04
# Epoch 34/50
# 110/112 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00056
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0017 - val_loss: 6.8201e-04 - learning_rate: 1.2500e-04
# Epoch 35/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020
# Epoch 35: val_loss did not improve from 0.00056
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0020 - val_loss: 8.4221e-04 - learning_rate: 6.2500e-05

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()

def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 27.56976420441999, MAE: 27.560939285321524, R2: -349317.4107210853

# %%
# Fetch data from Yahoo Finance
end_date = datetime.now().strftime('%Y-%m-%d')

aapl = yf.download("2222.SR", start="2024-01-01", end=end_date)
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 100
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual AAPL Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted AAPL Prices", color='red')
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
seq_length=100
# Prepare future prediction sequence
X_future = aapl_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024

future_dates = pd.date_range(start="2024-12-14", end="2024-12-22", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
