# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

# Download stock data for Leejam Sports Company (1830.SR)
leejam_stock = yf.download('1830.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
leejam_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open   Volume
# Ticker        1830.SR    1830.SR    1830.SR    1830.SR    1830.SR  1830.SR
# Date
# 2018-09-10  44.459999  51.000000  54.500000  50.200001  54.000000  1918555
# 2018-09-11  43.588230  50.000000  53.500000  49.900002  50.700001   931497
# 2018-09-12  43.588230  50.000000  52.099998  49.700001  50.500000   652157
# 2018-09-13  44.198475  50.700001  51.400002  50.000000  50.200001   384111
# 2018-09-16  43.588230  50.000000  51.099998  49.000000  50.900002   286693

# %%
plt.figure(figsize=(12, 6))
plt.plot(leejam_stock['Close'], label='Leejam Close Price')
plt.title('Leejam Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in leejam_stock.columns:
    leejam_stock['Date'] = leejam_stock.index
leejam_stock.set_index('Date', inplace=True)

leejam_prices = leejam_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
leejam_prices_scaled = scaler.fit_transform(leejam_prices)
joblib.dump(scaler, "leejam_scaler_5.joblib")  # Save the fitted scaler

# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(leejam_prices_scaled) * 0.8)
train_data = leejam_prices_scaled[:train_size]
test_data = leejam_prices_scaled[train_size:]

# Create sequences for LSTM model
# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 5 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 5])

    return np.array(sequences), np.array(labels)

seq_length = 100
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(5))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,005 (125.02 KB)
#  Trainable params: 32,005 (125.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_5.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0126
# Epoch 1: val_loss improved from inf to 0.01915, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0125 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 2/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.5745e-04
# Epoch 2: val_loss improved from 0.01915 to 0.00770, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 8.5738e-04 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 3/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.6302e-04
# Epoch 3: val_loss improved from 0.00770 to 0.00313, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 7.6241e-04 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 4/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.5501e-04
# Epoch 4: val_loss did not improve from 0.00313
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 6.5524e-04 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 5/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.7818e-04
# Epoch 5: val_loss improved from 0.00313 to 0.00257, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 5.7962e-04 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.2976e-04
# Epoch 6: val_loss improved from 0.00257 to 0.00236, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 7.2799e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 7/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.2172e-04
# Epoch 7: val_loss did not improve from 0.00236
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 6.2072e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 8/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8491e-04
# Epoch 8: val_loss did not improve from 0.00236
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 4.8566e-04 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 9/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.6469e-04
# Epoch 9: val_loss improved from 0.00236 to 0.00188, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 4.6501e-04 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 10/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.1621e-04
# Epoch 10: val_loss did not improve from 0.00188
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 4.1663e-04 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 11/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.6369e-04
# Epoch 11: val_loss did not improve from 0.00188
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 4.6379e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 12/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.4748e-04
# Epoch 12: val_loss improved from 0.00188 to 0.00188, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 4.4716e-04 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 13/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.3010e-04
# Epoch 13: val_loss did not improve from 0.00188
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 4.2978e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 14/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.7449e-04
# Epoch 14: val_loss did not improve from 0.00188
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 4.7426e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 15/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.5357e-04
# Epoch 15: val_loss improved from 0.00188 to 0.00170, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 3.5375e-04 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 16/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.1564e-04
# Epoch 16: val_loss improved from 0.00170 to 0.00169, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 4.1532e-04 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 17/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.0380e-04
# Epoch 17: val_loss did not improve from 0.00169
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 4.0319e-04 - val_loss: 0.0018 - learning_rate: 5.0000e-04
# Epoch 18/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.8642e-04
# Epoch 18: val_loss did not improve from 0.00169
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 3.8602e-04 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 19/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.3956e-04
# Epoch 19: val_loss did not improve from 0.00169
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 3.3961e-04 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 20/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.5984e-04
# Epoch 20: val_loss improved from 0.00169 to 0.00163, saving model to best_lstm_model_5.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 3.5954e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 21/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.5487e-04
# Epoch 21: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 3.5444e-04 - val_loss: 0.0016 - learning_rate: 2.5000e-04
# Epoch 22/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.4951e-04
# Epoch 22: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 3.4910e-04 - val_loss: 0.0018 - learning_rate: 2.5000e-04
# Epoch 23/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.3828e-04
# Epoch 23: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.3820e-04 - val_loss: 0.0017 - learning_rate: 2.5000e-04
# Epoch 24/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.3118e-04
# Epoch 24: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 3.3119e-04 - val_loss: 0.0016 - learning_rate: 2.5000e-04
# Epoch 25/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.2939e-04
# Epoch 25: val_loss did not improve from 0.00163
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 3.2931e-04 - val_loss: 0.0017 - learning_rate: 2.5000e-04
# Epoch 26/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0744e-04
# Epoch 26: val_loss improved from 0.00163 to 0.00163, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 3.0748e-04 - val_loss: 0.0016 - learning_rate: 1.2500e-04
# Epoch 27/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.9362e-04
# Epoch 27: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 2.9403e-04 - val_loss: 0.0017 - learning_rate: 1.2500e-04
# Epoch 28/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0195e-04
# Epoch 28: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 3.0214e-04 - val_loss: 0.0017 - learning_rate: 1.2500e-04
# Epoch 29/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.8691e-04
# Epoch 29: val_loss did not improve from 0.00163
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 2.8707e-04 - val_loss: 0.0017 - learning_rate: 1.2500e-04
# Epoch 30/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0920e-04
# Epoch 30: val_loss improved from 0.00163 to 0.00163, saving model to best_lstm_model_5.keras
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.0923e-04 - val_loss: 0.0016 - learning_rate: 1.2500e-04
# Epoch 31/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.0700e-04
# Epoch 31: val_loss improved from 0.00163 to 0.00162, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 3.0698e-04 - val_loss: 0.0016 - learning_rate: 6.2500e-05
# Epoch 32/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.9216e-04
# Epoch 32: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 2.9234e-04 - val_loss: 0.0017 - learning_rate: 6.2500e-05
# Epoch 33/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.2542e-04
# Epoch 33: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.2516e-04 - val_loss: 0.0017 - learning_rate: 6.2500e-05
# Epoch 34/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0497e-04
# Epoch 34: val_loss improved from 0.00162 to 0.00162, saving model to best_lstm_model_5.keras
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.0496e-04 - val_loss: 0.0016 - learning_rate: 6.2500e-05
# Epoch 35/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8726e-04
# Epoch 35: val_loss did not improve from 0.00162
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 2.8748e-04 - val_loss: 0.0017 - learning_rate: 6.2500e-05
# Epoch 36/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9983e-04
# Epoch 36: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 2.9985e-04 - val_loss: 0.0016 - learning_rate: 3.1250e-05
# Epoch 37/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.3402e-04
# Epoch 37: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.3357e-04 - val_loss: 0.0016 - learning_rate: 3.1250e-05
# Epoch 38/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0664e-04
# Epoch 38: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.0661e-04 - val_loss: 0.0016 - learning_rate: 3.1250e-05
# Epoch 39/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.1716e-04
# Epoch 39: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.1692e-04 - val_loss: 0.0017 - learning_rate: 3.1250e-05
# Epoch 40/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8890e-04
# Epoch 40: val_loss did not improve from 0.00162
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 2.8898e-04 - val_loss: 0.0016 - learning_rate: 3.1250e-05
# Epoch 41/50
# 143/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0344e-04
# Epoch 41: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.0334e-04 - val_loss: 0.0016 - learning_rate: 1.5625e-05
# Epoch 42/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.4977e-04
# Epoch 42: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 3.4942e-04 - val_loss: 0.0016 - learning_rate: 1.5625e-05
# Epoch 43/50
# 144/145 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.1096e-04
# Epoch 43: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 3.1076e-04 - val_loss: 0.0016 - learning_rate: 1.5625e-05
# Epoch 44/50
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8498e-04
# Epoch 44: val_loss did not improve from 0.00162
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 2.8508e-04 - val_loss: 0.0016 - learning_rate: 1.5625e-05

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()

def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 209.46443955676128, MAE: 208.94120035868696, R2: -7985632.813162187

# %%
# Fetch data from Yahoo Finance
end_date = datetime.now().strftime('%Y-%m-%d')

leejam_stock = yf.download("1830.SR", start="2024-01-01", end=end_date)
leejam_stock['Date'] = leejam_stock.index
leejam_prices = leejam_stock['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
leejam_prices_scaled = scaler.transform(leejam_prices)

# Create sequences for prediction
seq_length = 100
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(leejam_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(leejam_stock['Date'], leejam_stock['Close'], label="Actual Leejam Prices", color='blue')
plt.plot(leejam_stock['Date'][seq_length:], predictions_rescaled, label="Predicted Leejam Prices", color='red')
plt.title("Leejam Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
seq_length=100
# Prepare future prediction sequence
X_future = leejam_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024
future_dates = pd.date_range(start="2024-12-14", end="2024-12-22", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
