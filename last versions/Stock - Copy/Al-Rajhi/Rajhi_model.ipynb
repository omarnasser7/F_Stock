# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Fetch AAPL data from Yahoo Finance for the entire period from 2015 to the present
start_date = '2015-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

rajhi_stock = yf.download('1120.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
rajhi_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker        1120.SR    1120.SR    1120.SR    1120.SR    1120.SR   1120.SR
# Date
# 2015-01-01  14.455878  21.023432  21.328117  20.921867  21.226557   6688117
# 2015-01-04  14.595550  21.226557  21.429682  20.718742  20.921867   8714557
# 2015-01-05  14.316207  20.820307  21.124992  20.718742  20.921867   6415201
# 2015-01-06  14.386042  20.921867  21.023432  20.231243  20.414057  10596374
# 2015-01-07  14.316207  20.820307  21.124992  20.515617  20.820307  17053203

# %%
plt.figure(figsize=(12, 6))
plt.plot(rajhi_stock['Close'], label='GOOGL Close Price')
plt.title('AAPL Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in rajhi_stock.columns:
    rajhi_stock['Date'] = rajhi_stock.index
rajhi_stock.set_index('Date', inplace=True)

aapl_prices = rajhi_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "rajhi_scaler.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0061
# Epoch 1: val_loss improved from inf to 0.00064, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0060 - val_loss: 6.4220e-04 - learning_rate: 0.0010
# Epoch 2/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.2860e-04
# Epoch 2: val_loss improved from 0.00064 to 0.00042, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 6.2778e-04 - val_loss: 4.1812e-04 - learning_rate: 0.0010
# Epoch 3/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.8701e-04
# Epoch 3: val_loss improved from 0.00042 to 0.00038, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 3.8673e-04 - val_loss: 3.7772e-04 - learning_rate: 0.0010
# Epoch 4/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.3742e-04
# Epoch 4: val_loss did not improve from 0.00038
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 3.3748e-04 - val_loss: 4.9240e-04 - learning_rate: 0.0010
# Epoch 5/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.5983e-04
# Epoch 5: val_loss improved from 0.00038 to 0.00029, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 3.5931e-04 - val_loss: 2.9178e-04 - learning_rate: 0.0010
# Epoch 6/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7728e-04
# Epoch 6: val_loss did not improve from 0.00029
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 2.7728e-04 - val_loss: 9.8539e-04 - learning_rate: 0.0010
# Epoch 7/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1671e-04
# Epoch 7: val_loss did not improve from 0.00029
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 2.1653e-04 - val_loss: 4.6484e-04 - learning_rate: 0.0010
# Epoch 8/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0084e-04
# Epoch 8: val_loss did not improve from 0.00029
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 2.0099e-04 - val_loss: 5.1742e-04 - learning_rate: 0.0010
# Epoch 9/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9894e-04
# Epoch 9: val_loss improved from 0.00029 to 0.00024, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 1.9891e-04 - val_loss: 2.3867e-04 - learning_rate: 0.0010
# Epoch 10/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5193e-04
# Epoch 10: val_loss improved from 0.00024 to 0.00022, saving model to best_lstm_model.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 2.5160e-04 - val_loss: 2.2270e-04 - learning_rate: 0.0010
# Epoch 11/50
# 242/245 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2084e-04
# Epoch 11: val_loss did not improve from 0.00022
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 1.2101e-04 - val_loss: 3.7510e-04 - learning_rate: 5.0000e-04
# Epoch 12/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8341e-04
# Epoch 12: val_loss did not improve from 0.00022
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 1.8320e-04 - val_loss: 2.4990e-04 - learning_rate: 5.0000e-04
# Epoch 13/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1250e-04
# Epoch 13: val_loss did not improve from 0.00022
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 1.1252e-04 - val_loss: 3.8279e-04 - learning_rate: 5.0000e-04
# Epoch 14/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5319e-04
# Epoch 14: val_loss did not improve from 0.00022
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 1.5307e-04 - val_loss: 5.0429e-04 - learning_rate: 5.0000e-04
# Epoch 15/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1653e-04
# Epoch 15: val_loss improved from 0.00022 to 0.00020, saving model to best_lstm_model.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 1.1654e-04 - val_loss: 1.9700e-04 - learning_rate: 5.0000e-04
# Epoch 16/50
# 242/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0189e-04
# Epoch 16: val_loss improved from 0.00020 to 0.00019, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 1.0195e-04 - val_loss: 1.9187e-04 - learning_rate: 2.5000e-04
# Epoch 17/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0400e-04
# Epoch 17: val_loss did not improve from 0.00019
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 1.0400e-04 - val_loss: 2.2009e-04 - learning_rate: 2.5000e-04
# Epoch 18/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9697e-05
# Epoch 18: val_loss did not improve from 0.00019
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.9887e-05 - val_loss: 2.4503e-04 - learning_rate: 2.5000e-04
# Epoch 19/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0420e-04
# Epoch 19: val_loss improved from 0.00019 to 0.00019, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 1.0417e-04 - val_loss: 1.8971e-04 - learning_rate: 2.5000e-04
# Epoch 20/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3434e-04
# Epoch 20: val_loss did not improve from 0.00019
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 1.3419e-04 - val_loss: 2.7016e-04 - learning_rate: 2.5000e-04
# Epoch 21/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1768e-04
# Epoch 21: val_loss did not improve from 0.00019
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 1.1764e-04 - val_loss: 1.9298e-04 - learning_rate: 2.5000e-04
# Epoch 22/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0740e-04
# Epoch 22: val_loss did not improve from 0.00019
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 1.0735e-04 - val_loss: 2.1823e-04 - learning_rate: 2.5000e-04
# Epoch 23/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0676e-04
# Epoch 23: val_loss improved from 0.00019 to 0.00018, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 1.0676e-04 - val_loss: 1.7527e-04 - learning_rate: 2.5000e-04
# Epoch 24/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.6640e-05
# Epoch 24: val_loss did not improve from 0.00018
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.6705e-05 - val_loss: 4.4805e-04 - learning_rate: 2.5000e-04
# Epoch 25/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0805e-04
# Epoch 25: val_loss improved from 0.00018 to 0.00017, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 1.0799e-04 - val_loss: 1.6507e-04 - learning_rate: 1.2500e-04
# Epoch 26/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.8170e-05
# Epoch 26: val_loss improved from 0.00017 to 0.00016, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 6.8376e-05 - val_loss: 1.5924e-04 - learning_rate: 1.2500e-04
# Epoch 27/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8302e-05
# Epoch 27: val_loss improved from 0.00016 to 0.00016, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.8314e-05 - val_loss: 1.5879e-04 - learning_rate: 1.2500e-04
# Epoch 28/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1103e-05
# Epoch 28: val_loss improved from 0.00016 to 0.00016, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.1150e-05 - val_loss: 1.5831e-04 - learning_rate: 1.2500e-04
# Epoch 29/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.8857e-05
# Epoch 29: val_loss did not improve from 0.00016
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 9.8673e-05 - val_loss: 1.8991e-04 - learning_rate: 1.2500e-04
# Epoch 30/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7306e-05
# Epoch 30: val_loss improved from 0.00016 to 0.00015, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.7251e-05 - val_loss: 1.5348e-04 - learning_rate: 6.2500e-05
# Epoch 31/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0046e-04
# Epoch 31: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 1.0023e-04 - val_loss: 1.6141e-04 - learning_rate: 6.2500e-05
# Epoch 32/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8242e-05
# Epoch 32: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 7.8280e-05 - val_loss: 1.6761e-04 - learning_rate: 6.2500e-05
# Epoch 33/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3338e-05
# Epoch 33: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.3397e-05 - val_loss: 1.6748e-04 - learning_rate: 6.2500e-05
# Epoch 34/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1807e-05
# Epoch 34: val_loss improved from 0.00015 to 0.00015, saving model to best_lstm_model.keras
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 8.1777e-05 - val_loss: 1.5086e-04 - learning_rate: 6.2500e-05
# Epoch 35/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0785e-05
# Epoch 35: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.0830e-05 - val_loss: 1.7855e-04 - learning_rate: 3.1250e-05
# Epoch 36/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4255e-05
# Epoch 36: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.4226e-05 - val_loss: 1.6961e-04 - learning_rate: 3.1250e-05
# Epoch 37/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4339e-05
# Epoch 37: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.4358e-05 - val_loss: 1.5205e-04 - learning_rate: 3.1250e-05
# Epoch 38/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6611e-05
# Epoch 38: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.6611e-05 - val_loss: 1.5228e-04 - learning_rate: 3.1250e-05
# Epoch 39/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.2354e-05
# Epoch 39: val_loss improved from 0.00015 to 0.00015, saving model to best_lstm_model.keras
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.2392e-05 - val_loss: 1.4883e-04 - learning_rate: 3.1250e-05
# Epoch 40/50
# 242/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2362e-05
# Epoch 40: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 7.2441e-05 - val_loss: 1.5144e-04 - learning_rate: 1.5625e-05
# Epoch 41/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9652e-05
# Epoch 41: val_loss improved from 0.00015 to 0.00015, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 6.9698e-05 - val_loss: 1.4833e-04 - learning_rate: 1.5625e-05
# Epoch 42/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6696e-05
# Epoch 42: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.6681e-05 - val_loss: 1.6260e-04 - learning_rate: 1.5625e-05
# Epoch 43/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.5426e-05
# Epoch 43: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 7.5434e-05 - val_loss: 1.4849e-04 - learning_rate: 1.5625e-05
# Epoch 44/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.6979e-05
# Epoch 44: val_loss improved from 0.00015 to 0.00015, saving model to best_lstm_model.keras
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 6.7047e-05 - val_loss: 1.4772e-04 - learning_rate: 1.5625e-05
# Epoch 45/50
# 242/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3038e-05
# Epoch 45: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 8.2903e-05 - val_loss: 1.4894e-04 - learning_rate: 7.8125e-06
# Epoch 46/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5943e-05
# Epoch 46: val_loss improved from 0.00015 to 0.00015, saving model to best_lstm_model.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.5934e-05 - val_loss: 1.4747e-04 - learning_rate: 7.8125e-06
# Epoch 47/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9517e-05
# Epoch 47: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 6.9566e-05 - val_loss: 1.4814e-04 - learning_rate: 7.8125e-06
# Epoch 48/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6242e-05
# Epoch 48: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 7.6234e-05 - val_loss: 1.5100e-04 - learning_rate: 7.8125e-06
# Epoch 49/50
# 243/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0218e-05
# Epoch 49: val_loss did not improve from 0.00015
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.0262e-05 - val_loss: 1.5040e-04 - learning_rate: 7.8125e-06
# Epoch 50/50
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7328e-05
# Epoch 50: val_loss did not improve from 0.00015
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 7.7299e-05 - val_loss: 1.4880e-04 - learning_rate: 3.9063e-06

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(rajhi_stock.index[train_size:], rajhi_stock['Close'][train_size:], label='Actual Al-Rajhi Stock Price')
plt.plot(rajhi_stock.index[train_size + seq_length:], predictions, label='Predicted Al-Rajhi Stock Price')
plt.title('Al-Rajhi Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test, predictions)
# Out:
# RMSE: 79.2283564087472, MAE: 78.89089780241777, R2: -1040441.7458164785

# %%
# Fetch data from Yahoo Finance
rajhi = yf.download("1120.SR", start="2024-01-01", end="2024-11-30")
rajhi['Date'] = rajhi.index
aapl_prices = rajhi['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(rajhi['Date'], rajhi['Close'], label="Actual Al-Rajhi Prices", color='blue')
plt.plot(rajhi['Date'][seq_length:], predictions_rescaled, label="Predicted Al-Rajhi Prices", color='red')
plt.title("Al-Rajhi Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
