# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Fetch AAPL data from Yahoo Finance for the entire period from 2015 to the present
start_date = '2015-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

rajhi_stock = yf.download('1120.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
rajhi_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker        1120.SR    1120.SR    1120.SR    1120.SR    1120.SR   1120.SR
# Date
# 2015-01-01  14.455881  21.023432  21.328117  20.921867  21.226557   6688117
# 2015-01-04  14.595548  21.226557  21.429682  20.718742  20.921867   8714557
# 2015-01-05  14.316207  20.820307  21.124992  20.718742  20.921867   6415201
# 2015-01-06  14.386040  20.921867  21.023432  20.231243  20.414057  10596374
# 2015-01-07  14.316207  20.820307  21.124992  20.515617  20.820307  17053203

# %%
plt.figure(figsize=(12, 6))
plt.plot(rajhi_stock['Close'], label='AL-Rajhi Close Price')
plt.title('AL-Rajhi Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in rajhi_stock.columns:
    rajhi_stock['Date'] = rajhi_stock.index
rajhi_stock.set_index('Date', inplace=True)

aapl_prices = rajhi_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "rajhi_scaler_5.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 5 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 5])

    return np.array(sequences), np.array(labels)

seq_length = 100
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(5))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,005 (125.02 KB)
#  Trainable params: 32,005 (125.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_5.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=60, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0119
# Epoch 1: val_loss improved from inf to 0.00084, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - loss: 0.0118 - val_loss: 8.3843e-04 - learning_rate: 0.0010
# Epoch 2/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0011
# Epoch 2: val_loss did not improve from 0.00084
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0011 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 3/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.4726e-04
# Epoch 3: val_loss did not improve from 0.00084
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 6.4724e-04 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 4/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.1047e-04
# Epoch 4: val_loss did not improve from 0.00084
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 6.1088e-04 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 5/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.2311e-04
# Epoch 5: val_loss improved from 0.00084 to 0.00058, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 8.2201e-04 - val_loss: 5.7846e-04 - learning_rate: 0.0010
# Epoch 6/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.0927e-04
# Epoch 6: val_loss did not improve from 0.00058
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 5.0951e-04 - val_loss: 6.0931e-04 - learning_rate: 0.0010
# Epoch 7/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.5096e-04
# Epoch 7: val_loss did not improve from 0.00058
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 4.5091e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 8/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.6185e-04
# Epoch 8: val_loss improved from 0.00058 to 0.00052, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 4.6149e-04 - val_loss: 5.2440e-04 - learning_rate: 0.0010
# Epoch 9/60
# 238/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.1751e-04
# Epoch 9: val_loss did not improve from 0.00052
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 4.1769e-04 - val_loss: 8.8653e-04 - learning_rate: 0.0010
# Epoch 10/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.3694e-04
# Epoch 10: val_loss did not improve from 0.00052
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 4.3688e-04 - val_loss: 9.0816e-04 - learning_rate: 0.0010
# Epoch 11/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.8690e-04
# Epoch 11: val_loss did not improve from 0.00052
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 3.8641e-04 - val_loss: 7.2244e-04 - learning_rate: 5.0000e-04
# Epoch 12/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.1628e-04
# Epoch 12: val_loss improved from 0.00052 to 0.00047, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 3.1620e-04 - val_loss: 4.7474e-04 - learning_rate: 5.0000e-04
# Epoch 13/60
# 238/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.2848e-04
# Epoch 13: val_loss did not improve from 0.00047
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 3.2840e-04 - val_loss: 5.5665e-04 - learning_rate: 5.0000e-04
# Epoch 14/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0642e-04
# Epoch 14: val_loss did not improve from 0.00047
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 3.0646e-04 - val_loss: 5.1392e-04 - learning_rate: 5.0000e-04
# Epoch 15/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9351e-04
# Epoch 15: val_loss did not improve from 0.00047
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 2.9362e-04 - val_loss: 6.2927e-04 - learning_rate: 5.0000e-04
# Epoch 16/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8579e-04
# Epoch 16: val_loss did not improve from 0.00047
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.8605e-04 - val_loss: 5.1790e-04 - learning_rate: 5.0000e-04
# Epoch 17/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.1639e-04
# Epoch 17: val_loss did not improve from 0.00047
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 3.1620e-04 - val_loss: 5.7371e-04 - learning_rate: 5.0000e-04
# Epoch 18/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6773e-04
# Epoch 18: val_loss improved from 0.00047 to 0.00045, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.6776e-04 - val_loss: 4.4642e-04 - learning_rate: 2.5000e-04
# Epoch 19/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0378e-04
# Epoch 19: val_loss improved from 0.00045 to 0.00044, saving model to best_lstm_model_5.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 3.0368e-04 - val_loss: 4.4171e-04 - learning_rate: 2.5000e-04
# Epoch 20/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6504e-04
# Epoch 20: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.6516e-04 - val_loss: 4.5189e-04 - learning_rate: 2.5000e-04
# Epoch 21/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.5806e-04
# Epoch 21: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.5812e-04 - val_loss: 8.7777e-04 - learning_rate: 2.5000e-04
# Epoch 22/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.7927e-04
# Epoch 22: val_loss did not improve from 0.00044
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.7925e-04 - val_loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 23/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9320e-04
# Epoch 23: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.9292e-04 - val_loss: 4.6858e-04 - learning_rate: 1.2500e-04
# Epoch 24/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.3424e-04
# Epoch 24: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.3429e-04 - val_loss: 4.5426e-04 - learning_rate: 1.2500e-04
# Epoch 25/60
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.3392e-04
# Epoch 25: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.3397e-04 - val_loss: 5.1294e-04 - learning_rate: 1.2500e-04
# Epoch 26/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.4601e-04
# Epoch 26: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.4598e-04 - val_loss: 4.4719e-04 - learning_rate: 1.2500e-04
# Epoch 27/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.1279e-04
# Epoch 27: val_loss did not improve from 0.00044
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.1308e-04 - val_loss: 4.7100e-04 - learning_rate: 1.2500e-04
# Epoch 28/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.3679e-04
# Epoch 28: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 2.3682e-04 - val_loss: 4.9230e-04 - learning_rate: 6.2500e-05
# Epoch 29/60
# 239/240 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6300e-04
# Epoch 29: val_loss did not improve from 0.00044
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 2.6279e-04 - val_loss: 4.4417e-04 - learning_rate: 6.2500e-05

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 79.91725673553807, MAE: 79.58645378968804, R2: -1013595.2033854136

# %%
# Fetch data from Yahoo Finance
end_date = datetime.now().strftime('%Y-%m-%d')
rajhi = yf.download("1120.SR", start="2024-01-01", end=end_date)
rajhi['Date'] = rajhi.index
aapl_prices = rajhi['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 120
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(rajhi['Date'], rajhi['Close'], label="Actual Al-Rajhi Prices", color='blue')
plt.plot(rajhi['Date'][seq_length:], predictions_rescaled, label="Predicted Al-Rajhi Prices", color='red')
plt.title("Al-Rajhi Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
seq_length=120
# Prepare future prediction sequence
X_future = aapl_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024
s_date = datetime.now().strftime('%Y-%m-%d')
future_dates = pd.date_range(start=s_date, end="2024-12-21", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
