# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

aramco_stock = yf.download('2222.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aramco_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker        2222.SR    2222.SR    2222.SR    2222.SR    2222.SR    2222.SR
# Date
# 2019-12-11  25.042082  29.090908  29.090908  29.090908  29.090908   38289394
# 2019-12-12  26.180361  30.413223  31.983471  29.752066  31.983471  505692621
# 2019-12-15  26.607208  30.909090  30.991735  30.413223  30.661158   98349281
# 2019-12-16  27.034067  31.404959  31.487602  30.991735  30.991735  105973907
# 2019-12-17  26.856209  31.198347  31.528925  30.991735  31.446280  142672245

# %%
plt.figure(figsize=(12, 6))
plt.plot(aramco_stock['Close'], label='Aramco Close Price')
plt.title('Aramco Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in aramco_stock.columns:
    aramco_stock['Date'] = aramco_stock.index
aramco_stock.set_index('Date', inplace=True)

aapl_prices = aramco_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "aramco_stock.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0241
# Epoch 1: val_loss improved from inf to 0.00142, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0238 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 2/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027
# Epoch 2: val_loss did not improve from 0.00142
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0027 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 3/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028
# Epoch 3: val_loss improved from 0.00142 to 0.00062, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0028 - val_loss: 6.2238e-04 - learning_rate: 0.0010
# Epoch 4/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030
# Epoch 4: val_loss improved from 0.00062 to 0.00044, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0029 - val_loss: 4.4121e-04 - learning_rate: 0.0010
# Epoch 5/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020
# Epoch 5: val_loss did not improve from 0.00044
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0020 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028
# Epoch 6: val_loss did not improve from 0.00044
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0028 - val_loss: 4.5300e-04 - learning_rate: 0.0010
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018
# Epoch 7: val_loss did not improve from 0.00044
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0018 - val_loss: 6.4526e-04 - learning_rate: 0.0010
# Epoch 8/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018
# Epoch 8: val_loss improved from 0.00044 to 0.00032, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0018 - val_loss: 3.2472e-04 - learning_rate: 0.0010
# Epoch 9/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0016
# Epoch 9: val_loss improved from 0.00032 to 0.00029, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0016 - val_loss: 2.9408e-04 - learning_rate: 0.0010
# Epoch 10/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012
# Epoch 10: val_loss did not improve from 0.00029
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0012 - val_loss: 4.3556e-04 - learning_rate: 0.0010
# Epoch 11/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010
# Epoch 11: val_loss improved from 0.00029 to 0.00028, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0010 - val_loss: 2.7513e-04 - learning_rate: 0.0010
# Epoch 12/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0010
# Epoch 12: val_loss improved from 0.00028 to 0.00023, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0010 - val_loss: 2.2656e-04 - learning_rate: 0.0010
# Epoch 13/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.5922e-04
# Epoch 13: val_loss improved from 0.00023 to 0.00021, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 7.5927e-04 - val_loss: 2.1052e-04 - learning_rate: 0.0010
# Epoch 14/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.7575e-04
# Epoch 14: val_loss improved from 0.00021 to 0.00021, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 7.7704e-04 - val_loss: 2.0583e-04 - learning_rate: 0.0010
# Epoch 15/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.7574e-04
# Epoch 15: val_loss improved from 0.00021 to 0.00019, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 6.7608e-04 - val_loss: 1.8558e-04 - learning_rate: 0.0010
# Epoch 16/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.7485e-04
# Epoch 16: val_loss improved from 0.00019 to 0.00018, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 8.7369e-04 - val_loss: 1.8240e-04 - learning_rate: 0.0010
# Epoch 17/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.4213e-04
# Epoch 17: val_loss did not improve from 0.00018
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 7.4174e-04 - val_loss: 2.0854e-04 - learning_rate: 0.0010
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2861e-04
# Epoch 18: val_loss did not improve from 0.00018
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 7.2850e-04 - val_loss: 2.2362e-04 - learning_rate: 0.0010
# Epoch 19/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5795e-04
# Epoch 19: val_loss improved from 0.00018 to 0.00017, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 5.5765e-04 - val_loss: 1.7050e-04 - learning_rate: 5.0000e-04
# Epoch 20/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4211e-04
# Epoch 20: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.4223e-04 - val_loss: 2.0605e-04 - learning_rate: 5.0000e-04
# Epoch 21/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3467e-04
# Epoch 21: val_loss improved from 0.00017 to 0.00017, saving model to best_lstm_model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.3622e-04 - val_loss: 1.6867e-04 - learning_rate: 5.0000e-04
# Epoch 22/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.4519e-04
# Epoch 22: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.4865e-04 - val_loss: 2.1878e-04 - learning_rate: 5.0000e-04
# Epoch 23/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7629e-04
# Epoch 23: val_loss did not improve from 0.00017
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.7648e-04 - val_loss: 1.8855e-04 - learning_rate: 5.0000e-04
# Epoch 24/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3869e-04
# Epoch 24: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 7.3588e-04 - val_loss: 1.7897e-04 - learning_rate: 2.5000e-04
# Epoch 25/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8917e-04
# Epoch 25: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9093e-04 - val_loss: 2.9954e-04 - learning_rate: 2.5000e-04
# Epoch 26/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.4452e-04
# Epoch 26: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.4174e-04 - val_loss: 1.8968e-04 - learning_rate: 2.5000e-04
# Epoch 27/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3339e-04
# Epoch 27: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.3360e-04 - val_loss: 2.0661e-04 - learning_rate: 2.5000e-04
# Epoch 28/50
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5532e-04
# Epoch 28: val_loss did not improve from 0.00017
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.5506e-04 - val_loss: 1.8402e-04 - learning_rate: 2.5000e-04
# Epoch 29/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0974e-04
# Epoch 29: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0969e-04 - val_loss: 1.6900e-04 - learning_rate: 1.2500e-04
# Epoch 30/50
# 115/118 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9777e-04
# Epoch 30: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9815e-04 - val_loss: 2.5134e-04 - learning_rate: 1.2500e-04
# Epoch 31/50
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5650e-04
# Epoch 31: val_loss did not improve from 0.00017
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.5748e-04 - val_loss: 1.7250e-04 - learning_rate: 1.2500e-04

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(aramco_stock.index[train_size:], aramco_stock['Close'][train_size:], label='Actual AAPL Stock Price')
plt.plot(aramco_stock.index[train_size + seq_length:], predictions, label='Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test, predictions)
# Out:
# RMSE: 28.244045760630556, MAE: 28.214773789076343, R2: -102890.27414437762

# %%
# Fetch data from Yahoo Finance
aapl = yf.download("2222.SR", start="2024-01-01", end="2024-11-30")
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual AAPL Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted AAPL Prices", color='red')
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
