# %%
import yfinance as yf
from datetime import datetime
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

amzn_stock = yf.download('AMZN', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
amzn_stock.head()
# Out:
# Price      Adj Close   Close    High     Low    Open     Volume
# Ticker          AMZN    AMZN    AMZN    AMZN    AMZN       AMZN
# Date
# 2010-01-04    6.6950  6.6950  6.8305  6.6570  6.8125  151998000
# 2010-01-05    6.7345  6.7345  6.7740  6.5905  6.6715  177038000
# 2010-01-06    6.6125  6.6125  6.7365  6.5825  6.7300  143576000
# 2010-01-07    6.5000  6.5000  6.6160  6.4400  6.6005  220604000
# 2010-01-08    6.6760  6.6760  6.6840  6.4515  6.5280  196610000

# %%
plt.figure(figsize=(12, 6))
plt.plot(amzn_stock['Close'], label='Amazon Close Price')
plt.title('Amazon Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in amzn_stock.columns:
    amzn_stock['Date'] = amzn_stock.index
amzn_stock.set_index('Date', inplace=True)

aapl_prices = amzn_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "amazon_scaler.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044
# Epoch 1: val_loss improved from inf to 0.00110, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0043 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 2/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5950e-04
# Epoch 2: val_loss did not improve from 0.00110
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.5953e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 3/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7564e-04
# Epoch 3: val_loss improved from 0.00110 to 0.00099, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.7572e-04 - val_loss: 9.9183e-04 - learning_rate: 0.0010
# Epoch 4/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0686e-04
# Epoch 4: val_loss improved from 0.00099 to 0.00075, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 2.0688e-04 - val_loss: 7.4984e-04 - learning_rate: 0.0010
# Epoch 5/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0266e-04
# Epoch 5: val_loss did not improve from 0.00075
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.0255e-04 - val_loss: 8.9033e-04 - learning_rate: 0.0010
# Epoch 6/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4110e-04
# Epoch 6: val_loss did not improve from 0.00075
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.4118e-04 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 7/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3193e-04
# Epoch 7: val_loss did not improve from 0.00075
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.3176e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 8/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5757e-04
# Epoch 8: val_loss improved from 0.00075 to 0.00045, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.5754e-04 - val_loss: 4.4554e-04 - learning_rate: 0.0010
# Epoch 9/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1123e-04
# Epoch 9: val_loss did not improve from 0.00045
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.1130e-04 - val_loss: 5.0970e-04 - learning_rate: 0.0010
# Epoch 10/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4033e-04
# Epoch 10: val_loss improved from 0.00045 to 0.00035, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.4026e-04 - val_loss: 3.4607e-04 - learning_rate: 0.0010
# Epoch 11/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1052e-04
# Epoch 11: val_loss improved from 0.00035 to 0.00031, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.1050e-04 - val_loss: 3.1253e-04 - learning_rate: 0.0010
# Epoch 12/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1072e-04
# Epoch 12: val_loss did not improve from 0.00031
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1074e-04 - val_loss: 6.6718e-04 - learning_rate: 0.0010
# Epoch 13/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0793e-04
# Epoch 13: val_loss did not improve from 0.00031
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.0789e-04 - val_loss: 4.5597e-04 - learning_rate: 0.0010
# Epoch 14/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6747e-05
# Epoch 14: val_loss did not improve from 0.00031
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.6772e-05 - val_loss: 3.5483e-04 - learning_rate: 0.0010
# Epoch 15/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1148e-05
# Epoch 15: val_loss improved from 0.00031 to 0.00029, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.1258e-05 - val_loss: 2.8839e-04 - learning_rate: 0.0010
# Epoch 16/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.2795e-05
# Epoch 16: val_loss improved from 0.00029 to 0.00023, saving model to best_lstm_model.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 7.2854e-05 - val_loss: 2.3224e-04 - learning_rate: 0.0010
# Epoch 17/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.8057e-05
# Epoch 17: val_loss improved from 0.00023 to 0.00023, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 5.8048e-05 - val_loss: 2.2637e-04 - learning_rate: 5.0000e-04
# Epoch 18/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5100e-05
# Epoch 18: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 5.5126e-05 - val_loss: 3.1581e-04 - learning_rate: 5.0000e-04
# Epoch 19/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.1434e-05
# Epoch 19: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 6.1423e-05 - val_loss: 2.3381e-04 - learning_rate: 5.0000e-04
# Epoch 20/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.8008e-05
# Epoch 20: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 5.8006e-05 - val_loss: 2.2698e-04 - learning_rate: 5.0000e-04
# Epoch 21/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9154e-05
# Epoch 21: val_loss did not improve from 0.00023
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.9172e-05 - val_loss: 2.5174e-04 - learning_rate: 5.0000e-04
# Epoch 22/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3299e-05
# Epoch 22: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 5.3265e-05 - val_loss: 2.6117e-04 - learning_rate: 2.5000e-04
# Epoch 23/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2050e-05
# Epoch 23: val_loss improved from 0.00023 to 0.00022, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 5.2028e-05 - val_loss: 2.2028e-04 - learning_rate: 2.5000e-04
# Epoch 24/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2325e-05
# Epoch 24: val_loss did not improve from 0.00022
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 5.2318e-05 - val_loss: 2.2342e-04 - learning_rate: 2.5000e-04
# Epoch 25/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5495e-05
# Epoch 25: val_loss did not improve from 0.00022
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.5522e-05 - val_loss: 2.5203e-04 - learning_rate: 2.5000e-04
# Epoch 26/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0084e-05
# Epoch 26: val_loss did not improve from 0.00022
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 5.0095e-05 - val_loss: 2.2531e-04 - learning_rate: 2.5000e-04
# Epoch 27/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3906e-05
# Epoch 27: val_loss did not improve from 0.00022
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.3909e-05 - val_loss: 3.0291e-04 - learning_rate: 1.2500e-04
# Epoch 28/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3953e-05
# Epoch 28: val_loss improved from 0.00022 to 0.00022, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.3963e-05 - val_loss: 2.1885e-04 - learning_rate: 1.2500e-04
# Epoch 29/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.2567e-05
# Epoch 29: val_loss did not improve from 0.00022
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.2546e-05 - val_loss: 2.2014e-04 - learning_rate: 1.2500e-04
# Epoch 30/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.4824e-05
# Epoch 30: val_loss did not improve from 0.00022
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.4828e-05 - val_loss: 2.4777e-04 - learning_rate: 1.2500e-04
# Epoch 31/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.4900e-05
# Epoch 31: val_loss did not improve from 0.00022
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.4891e-05 - val_loss: 3.0543e-04 - learning_rate: 1.2500e-04
# Epoch 32/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5432e-05
# Epoch 32: val_loss improved from 0.00022 to 0.00021, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.5411e-05 - val_loss: 2.1321e-04 - learning_rate: 6.2500e-05
# Epoch 33/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0143e-05
# Epoch 33: val_loss improved from 0.00021 to 0.00021, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.0151e-05 - val_loss: 2.1294e-04 - learning_rate: 6.2500e-05
# Epoch 34/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3818e-05
# Epoch 34: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.3815e-05 - val_loss: 2.4893e-04 - learning_rate: 6.2500e-05
# Epoch 35/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0151e-05
# Epoch 35: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.0160e-05 - val_loss: 2.1496e-04 - learning_rate: 6.2500e-05
# Epoch 36/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8860e-05
# Epoch 36: val_loss did not improve from 0.00021
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.8889e-05 - val_loss: 2.1978e-04 - learning_rate: 6.2500e-05
# Epoch 37/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.7486e-05
# Epoch 37: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.7510e-05 - val_loss: 2.1696e-04 - learning_rate: 3.1250e-05
# Epoch 38/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3798e-05
# Epoch 38: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.3767e-05 - val_loss: 2.1303e-04 - learning_rate: 3.1250e-05
# Epoch 39/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2247e-05
# Epoch 39: val_loss improved from 0.00021 to 0.00021, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.2238e-05 - val_loss: 2.1187e-04 - learning_rate: 3.1250e-05
# Epoch 40/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3214e-05
# Epoch 40: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.3203e-05 - val_loss: 2.3356e-04 - learning_rate: 3.1250e-05
# Epoch 41/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2423e-05
# Epoch 41: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.2400e-05 - val_loss: 2.1192e-04 - learning_rate: 3.1250e-05
# Epoch 42/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.4896e-05
# Epoch 42: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.4871e-05 - val_loss: 2.1444e-04 - learning_rate: 3.1250e-05
# Epoch 43/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2977e-05
# Epoch 43: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.2958e-05 - val_loss: 2.1268e-04 - learning_rate: 3.1250e-05
# Epoch 44/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.9010e-05
# Epoch 44: val_loss did not improve from 0.00021
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.9029e-05 - val_loss: 2.1219e-04 - learning_rate: 3.1250e-05
# Epoch 45/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3579e-05
# Epoch 45: val_loss improved from 0.00021 to 0.00021, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.3630e-05 - val_loss: 2.1184e-04 - learning_rate: 1.5625e-05
# Epoch 46/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.1880e-05
# Epoch 46: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.1867e-05 - val_loss: 2.1353e-04 - learning_rate: 1.5625e-05
# Epoch 47/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.1645e-05
# Epoch 47: val_loss improved from 0.00021 to 0.00021, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.1637e-05 - val_loss: 2.1180e-04 - learning_rate: 1.5625e-05
# Epoch 48/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0264e-05
# Epoch 48: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.0262e-05 - val_loss: 2.1186e-04 - learning_rate: 1.5625e-05
# Epoch 49/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.9709e-05
# Epoch 49: val_loss did not improve from 0.00021
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.9712e-05 - val_loss: 2.1314e-04 - learning_rate: 1.5625e-05
# Epoch 50/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.8299e-05
# Epoch 50: val_loss did not improve from 0.00021
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.8302e-05 - val_loss: 2.1876e-04 - learning_rate: 7.8125e-06

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(amzn_stock.index[train_size:], amzn_stock['Close'][train_size:], label='Actual Amazon Stock Price')
plt.plot(amzn_stock.index[train_size + seq_length:], predictions, label='Predicted Amazon Stock Price')
plt.title('Amazon Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test, predictions)
# Out:
# RMSE: 145.1822016677552, MAE: 141.19699144194993, R2: -872996.0558456217

# %%
# Fetch data from Yahoo Finance
aapl = yf.download("AMZN", start="2024-01-01", end="2024-11-30")
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual Amazon Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted Amazon Prices", color='red')
plt.title("Amazon Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
