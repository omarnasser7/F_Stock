# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import joblib

# %%
# Fetch AAPL data from Yahoo Finance for the entire period from 2015 to the present
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

aapl_stock = yf.download('AAPL', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_stock.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.447412  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.458559  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.355828  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.344079  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.386254  7.570714  7.571429  7.466429  7.510714  447610800

# %%
plt.figure(figsize=(12, 6))
plt.plot(aapl_stock['Close'], label='AAPL Close Price')
plt.title('AAPL Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in aapl_stock.columns:
    aapl_stock['Date'] = aapl_stock.index
aapl_stock.set_index('Date', inplace=True)

aapl_prices = aapl_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
# joblib.dump(scaler, "appl_scaler.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 20 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 20])

    return np.array(sequences), np.array(labels)

seq_length = 200
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
X_train.shape, y_train.shape
# Out:
# ((2791, 200, 1), (2791, 20, 1))

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(20))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 200, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,395 (126.54 KB)
#  Trainable params: 32,395 (126.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=150, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0062
# Epoch 1: val_loss improved from inf to 0.00492, saving model to best_lstm_model.keras
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 46s 108ms/step - loss: 0.0062 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 2/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 4.2025e-04
# Epoch 2: val_loss did not improve from 0.00492
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 81ms/step - loss: 4.2035e-04 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 3/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 3.3319e-04
# Epoch 3: val_loss did not improve from 0.00492
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - loss: 3.3326e-04 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 4/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 3.2326e-04
# Epoch 4: val_loss improved from 0.00492 to 0.00302, saving model to best_lstm_model.keras
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - loss: 3.2326e-04 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 5/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 2.9876e-04
# Epoch 5: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - loss: 2.9878e-04 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 6/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 3.1391e-04
# Epoch 6: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 40s 113ms/step - loss: 3.1392e-04 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 7/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 3.5707e-04
# Epoch 7: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 38s 110ms/step - loss: 3.5686e-04 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 8/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 2.9644e-04
# Epoch 8: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 42s 119ms/step - loss: 2.9642e-04 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 9/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 2.7872e-04
# Epoch 9: val_loss did not improve from 0.00302
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 36s 104ms/step - loss: 2.7872e-04 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 10/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.3136e-04
# Epoch 10: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 34s 98ms/step - loss: 2.3138e-04 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 11/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.1780e-04
# Epoch 11: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 30s 85ms/step - loss: 2.1784e-04 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 12/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.2837e-04
# Epoch 12: val_loss did not improve from 0.00302
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 31s 87ms/step - loss: 2.2839e-04 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 13/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2.3131e-04
# Epoch 13: val_loss improved from 0.00302 to 0.00268, saving model to best_lstm_model.keras
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 84ms/step - loss: 2.3133e-04 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 14/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.0562e-04
# Epoch 14: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 30s 85ms/step - loss: 2.0566e-04 - val_loss: 0.0060 - learning_rate: 5.0000e-04
# Epoch 15/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2.3027e-04
# Epoch 15: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - loss: 2.3024e-04 - val_loss: 0.0039 - learning_rate: 5.0000e-04
# Epoch 16/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2.1723e-04
# Epoch 16: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 30s 85ms/step - loss: 2.1726e-04 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 17/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2.2232e-04
# Epoch 17: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - loss: 2.2236e-04 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 18/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2.5113e-04
# Epoch 18: val_loss did not improve from 0.00268
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - loss: 2.5109e-04 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 19/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2.0689e-04
# Epoch 19: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - loss: 2.0689e-04 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 20/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2.2310e-04
# Epoch 20: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 84ms/step - loss: 2.2306e-04 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 21/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8947e-04
# Epoch 21: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - loss: 1.8951e-04 - val_loss: 0.0042 - learning_rate: 2.5000e-04
# Epoch 22/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2.1527e-04
# Epoch 22: val_loss did not improve from 0.00268
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 28s 81ms/step - loss: 2.1525e-04 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 23/150
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.9447e-04
# Epoch 23: val_loss did not improve from 0.00268
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - loss: 1.9451e-04 - val_loss: 0.0042 - learning_rate: 2.5000e-04

# %%
predictions = model.predict(X_test)
predictions_rescaled = scaler.inverse_transform(predictions)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step

# %%
predictions.shape
# Out:
# (534, 20)

# %%
y_test.shape
# Out:
# (534, 20, 1)

# %%
# Reshape y_test to match the shape of predictions
y_test_reshaped = y_test.squeeze()  # This removes the last dimension, changing (679, 15, 1) to (679, 15)

# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

# Call the function with reshaped y_test
evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 0.051761780101435714, MAE: 0.03998768774283261, R2: 0.7983385183939571

# %%
out = scaler.inverse_transform(y_test[-1])

# %%
out
# Out:
# array([[225.        ],
#        [228.02000427],
#        [228.27999878],
#        [229.        ],
#        [228.52000427],
#        [229.86999512],
#        [232.86999512],
#        [235.05999756],
#        [234.92999268],
#        [237.33000183],
#        [239.58999634],
#        [242.6499939 ],
#        [243.00999451],
#        [243.03999329],
#        [242.83999634],
#        [246.75      ],
#        [247.77000427],
#        [246.49000549],
#        [247.96000671],
#        [248.13000488]])

# %%
plt.plot(out)

# %%
plt.plot(predictions_rescaled[-1])

# %%
predictions_rescaled[-1]
# Out:
# array([213.59247, 210.88593, 210.45847, 213.44379, 216.63483, 211.34161,
#        212.32542, 202.42996, 217.30414, 200.72174, 206.57733, 204.38116,
#        206.07535, 207.84201, 216.25018, 209.08368, 203.02568, 213.55959,
#        215.51859, 216.20778], dtype=float32)

# %%
predictions[0]
# Out:
# array([0.5816135 , 0.58170635, 0.5774062 , 0.5716318 , 0.58733857,
#        0.585169  , 0.58888316, 0.5802403 , 0.5853811 , 0.5836986 ,
#        0.57836497, 0.58611035, 0.58356285, 0.5914087 , 0.58707494,
#        0.5864926 , 0.5920374 , 0.59928554, 0.60157007, 0.6069046 ],
#       dtype=float32)

# %%
y_test_reshaped[0]
# Out:
# array([0.57711467, 0.57835803, 0.57433765, 0.55220489, 0.55357265,
#        0.54760425, 0.54495163, 0.5642246 , 0.54511746, 0.56182066,
#        0.56737456, 0.56783048, 0.56588246, 0.58196398, 0.59099943,
#        0.60297765, 0.59058499, 0.57172653, 0.61706972, 0.60712237])

# %%
plt.plot(predictions[1])

# %%
plt.plot(y_test_reshaped[1])

# %%
# Prepare future prediction sequence
X_future = aapl_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
future_dates = pd.date_range(start=aapl.index[-1], periods=21, freq='B')[1:]  # Exclude last known date

# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual AAPL Prices", color='blue')  # Actual prices
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
# Match predictions to test dates
predictions_rescaled_single = predictions_rescaled[:, 0]  # Use the first predicted step
dates_test = aapl['Date'][train_size + seq_length:]  # Test dates after the training set + sequence length

# Generate future dates for November 2024 predictions
future_dates = pd.date_range(start=aapl.index[-1], periods=21, freq='B')[1:]  # 20 business days into the future

# Plot the predictions
plt.figure(figsize=(14, 7))

# Plot actual test prices (if available)
actual_prices_test = scaler.inverse_transform(test_data[seq_length:])
plt.plot(dates_test, actual_prices_test[:len(dates_test)], label="Actual AAPL Prices", color='blue')

# Plot rescaled predictions
plt.plot(dates_test[:len(predictions_rescaled_single)], predictions_rescaled_single, label="Predicted AAPL Prices (Test)", color='red')

# Plot November 2024 future predictions
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices (Future)", color='green')

plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 16
#      13 plt.plot(dates_test, actual_prices_test[:len(dates_test)], label="Actual AAPL Prices", color='blue')
#      15 # Plot rescaled predictions
# ---> 16 plt.plot(dates_test[:len(predictions_rescaled_single)], predictions_rescaled_single, label="Predicted AAPL Prices (Test)", color='red')
#      18 # Plot November 2024 future predictions
#      19 plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices (Future)", color='green')
#
# File c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:3708, in plot(scalex, scaley, data, *args, **kwargs)
#    3700 @_copy_docstring_and_deprecators(Axes.plot)
#    3701 def plot(
#    3702     *args: float | ArrayLike | str,
#    (...)
#    3706     **kwargs,
#    3707 ) -> list[Line2D]:
# -> 3708     return gca().plot(
#    3709         *args,
#    3710         scalex=scalex,
#    3711         scaley=scaley,
#    3712         **({"data": data} if data is not None else {}),
#    3713         **kwargs,
#    3714     )
#
# File c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (0,) and (1,)

# %%
# Fetch data from Yahoo Finance
aapl = yf.download("AAPL", start="2024-01-01", end="2024-11-30")
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual AAPL Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted AAPL Prices", color='red')
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
