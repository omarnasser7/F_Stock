# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Fetch AAPL data from Yahoo Finance for the entire period from 2015 to the present
start_date = '2015-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

rajhi_stock = yf.download('1120.SR', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
rajhi_stock.head()
# Out:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker        1120.SR    1120.SR    1120.SR    1120.SR    1120.SR   1120.SR
# Date
# 2015-01-01  14.455877  21.023432  21.328117  20.921867  21.226557   6688117
# 2015-01-04  14.595546  21.226557  21.429682  20.718742  20.921867   8714557
# 2015-01-05  14.316210  20.820307  21.124992  20.718742  20.921867   6415201
# 2015-01-06  14.386039  20.921867  21.023432  20.231243  20.414057  10596374
# 2015-01-07  14.316210  20.820307  21.124992  20.515617  20.820307  17053203

# %%
plt.figure(figsize=(12, 6))
plt.plot(rajhi_stock['Close'], label='AL-Rajhi Close Price')
plt.title('AL-Rajhi Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in rajhi_stock.columns:
    rajhi_stock['Date'] = rajhi_stock.index
rajhi_stock.set_index('Date', inplace=True)

aapl_prices = rajhi_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "rajhi_scaler_15.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 15 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 15])

    return np.array(sequences), np.array(labels)

seq_length = 120
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(15))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 120, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,265 (126.04 KB)
#  Trainable params: 32,265 (126.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_15.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=60, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0221
# Epoch 1: val_loss improved from inf to 0.00285, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - loss: 0.0220 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 2/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0014
# Epoch 2: val_loss improved from 0.00285 to 0.00177, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0014 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 3/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012
# Epoch 3: val_loss did not improve from 0.00177
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 0.0012 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 4/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013
# Epoch 4: val_loss improved from 0.00177 to 0.00129, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0013 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 5/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.3653e-04
# Epoch 5: val_loss did not improve from 0.00129
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.3647e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 6/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010
# Epoch 6: val_loss improved from 0.00129 to 0.00120, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0010 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 7/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.5247e-04
# Epoch 7: val_loss did not improve from 0.00120
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 8.5265e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 8/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.9042e-04
# Epoch 8: val_loss did not improve from 0.00120
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 8.9119e-04 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 9/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011
# Epoch 9: val_loss did not improve from 0.00120
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0011 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 10/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.4889e-04
# Epoch 10: val_loss did not improve from 0.00120
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.4901e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 11/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.8834e-04
# Epoch 11: val_loss did not improve from 0.00120
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.8886e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 12/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.5645e-04
# Epoch 12: val_loss improved from 0.00120 to 0.00101, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.5656e-04 - val_loss: 0.0010 - learning_rate: 5.0000e-04
# Epoch 13/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.4073e-04
# Epoch 13: val_loss did not improve from 0.00101
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 8.4028e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-04
# Epoch 14/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.5980e-04
# Epoch 14: val_loss did not improve from 0.00101
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.6022e-04 - val_loss: 0.0010 - learning_rate: 5.0000e-04
# Epoch 15/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.2053e-04
# Epoch 15: val_loss did not improve from 0.00101
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.2051e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 16/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.9041e-04
# Epoch 16: val_loss did not improve from 0.00101
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.9014e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 17/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.9270e-04
# Epoch 17: val_loss improved from 0.00101 to 0.00099, saving model to best_lstm_model_15.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - loss: 7.9244e-04 - val_loss: 9.9377e-04 - learning_rate: 5.0000e-04
# Epoch 18/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.1095e-04
# Epoch 18: val_loss did not improve from 0.00099
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 7.1103e-04 - val_loss: 0.0010 - learning_rate: 2.5000e-04
# Epoch 19/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.8615e-04
# Epoch 19: val_loss did not improve from 0.00099
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 6.8618e-04 - val_loss: 0.0021 - learning_rate: 2.5000e-04
# Epoch 20/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.9156e-04
# Epoch 20: val_loss did not improve from 0.00099
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.9142e-04 - val_loss: 0.0010 - learning_rate: 2.5000e-04
# Epoch 21/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.7305e-04
# Epoch 21: val_loss did not improve from 0.00099
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 5.7340e-04 - val_loss: 0.0011 - learning_rate: 2.5000e-04
# Epoch 22/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.8143e-04
# Epoch 22: val_loss did not improve from 0.00099
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.8134e-04 - val_loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 23/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.1568e-04
# Epoch 23: val_loss did not improve from 0.00099
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.1584e-04 - val_loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 24/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.7367e-04
# Epoch 24: val_loss improved from 0.00099 to 0.00095, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 6.7355e-04 - val_loss: 9.5353e-04 - learning_rate: 1.2500e-04
# Epoch 25/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.1245e-04
# Epoch 25: val_loss did not improve from 0.00095
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 7.1185e-04 - val_loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 26/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.1629e-04
# Epoch 26: val_loss did not improve from 0.00095
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.1643e-04 - val_loss: 9.5623e-04 - learning_rate: 1.2500e-04
# Epoch 27/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.3801e-04
# Epoch 27: val_loss did not improve from 0.00095
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.3808e-04 - val_loss: 9.9414e-04 - learning_rate: 1.2500e-04
# Epoch 28/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.1750e-04
# Epoch 28: val_loss did not improve from 0.00095
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 6.1751e-04 - val_loss: 0.0011 - learning_rate: 6.2500e-05
# Epoch 29/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.3111e-04
# Epoch 29: val_loss improved from 0.00095 to 0.00094, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.3102e-04 - val_loss: 9.3890e-04 - learning_rate: 6.2500e-05
# Epoch 30/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.2223e-04
# Epoch 30: val_loss improved from 0.00094 to 0.00094, saving model to best_lstm_model_15.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 6.2222e-04 - val_loss: 9.3870e-04 - learning_rate: 6.2500e-05
# Epoch 31/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.9740e-04
# Epoch 31: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 5.9747e-04 - val_loss: 0.0011 - learning_rate: 6.2500e-05
# Epoch 32/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.9861e-04
# Epoch 32: val_loss did not improve from 0.00094
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 5.9867e-04 - val_loss: 0.0011 - learning_rate: 6.2500e-05
# Epoch 33/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.0323e-04
# Epoch 33: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 6.0324e-04 - val_loss: 0.0011 - learning_rate: 3.1250e-05
# Epoch 34/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.9935e-04
# Epoch 34: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 5.9940e-04 - val_loss: 0.0012 - learning_rate: 3.1250e-05
# Epoch 35/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.3102e-04
# Epoch 35: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.3079e-04 - val_loss: 0.0011 - learning_rate: 3.1250e-05
# Epoch 36/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.9647e-04
# Epoch 36: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 5.9655e-04 - val_loss: 0.0011 - learning_rate: 3.1250e-05
# Epoch 37/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.0124e-04
# Epoch 37: val_loss did not improve from 0.00094
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - loss: 6.0124e-04 - val_loss: 0.0011 - learning_rate: 3.1250e-05
# Epoch 38/60
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.7758e-04
# Epoch 38: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 5.7778e-04 - val_loss: 0.0011 - learning_rate: 1.5625e-05
# Epoch 39/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.3380e-04
# Epoch 39: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.3365e-04 - val_loss: 0.0012 - learning_rate: 1.5625e-05
# Epoch 40/60
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.5910e-04
# Epoch 40: val_loss did not improve from 0.00094
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.5884e-04 - val_loss: 0.0011 - learning_rate: 1.5625e-05

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 80.10456910879593, MAE: 79.82189912260199, R2: -1017101.4434664238

# %%
# Fetch data from Yahoo Finance
end_date = datetime.now().strftime('%Y-%m-%d')
rajhi = yf.download("1120.SR", start="2024-01-01", end=end_date)
rajhi['Date'] = rajhi.index
aapl_prices = rajhi['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 120
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(rajhi['Date'], rajhi['Close'], label="Actual Al-Rajhi Prices", color='blue')
plt.plot(rajhi['Date'][seq_length:], predictions_rescaled, label="Predicted Al-Rajhi Prices", color='red')
plt.title("Al-Rajhi Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
seq_length=120
# Prepare future prediction sequence
X_future = aapl_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024
s_date = datetime.now().strftime('%Y-%m-%d')
future_dates = pd.date_range(start=s_date, end="2025-1-3", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted AAPL Prices", color='red')  # Predicted
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
