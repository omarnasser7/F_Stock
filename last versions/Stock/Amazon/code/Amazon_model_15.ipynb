# %%
import yfinance as yf
from datetime import datetime
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

amzn_stock = yf.download('AMZN', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
amzn_stock.head()
# Out:
# Price      Adj Close   Close    High     Low    Open     Volume
# Ticker          AMZN    AMZN    AMZN    AMZN    AMZN       AMZN
# Date
# 2010-01-04    6.6950  6.6950  6.8305  6.6570  6.8125  151998000
# 2010-01-05    6.7345  6.7345  6.7740  6.5905  6.6715  177038000
# 2010-01-06    6.6125  6.6125  6.7365  6.5825  6.7300  143576000
# 2010-01-07    6.5000  6.5000  6.6160  6.4400  6.6005  220604000
# 2010-01-08    6.6760  6.6760  6.6840  6.4515  6.5280  196610000

# %%
plt.figure(figsize=(12, 6))
plt.plot(amzn_stock['Close'], label='Amazon Close Price')
plt.title('Amazon Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in amzn_stock.columns:
    amzn_stock['Date'] = amzn_stock.index
amzn_stock.set_index('Date', inplace=True)

aapl_prices = amzn_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "amazon_scaler_15.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []

    for i in range(len(data) - seq_length - 15 + 1):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length:i + seq_length + 15])

    return np.array(sequences), np.array(labels)

seq_length = 120
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(15))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 120, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,265 (126.04 KB)
#  Trainable params: 32,265 (126.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model_15.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=60, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0100
# Epoch 1: val_loss improved from inf to 0.00256, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - loss: 0.0099 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 2/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.3621e-04
# Epoch 2: val_loss improved from 0.00256 to 0.00199, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 6.3607e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 3/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.8439e-04
# Epoch 3: val_loss did not improve from 0.00199
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 4.8458e-04 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 4/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.4621e-04
# Epoch 4: val_loss improved from 0.00199 to 0.00196, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 6.4597e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 5/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.6809e-04
# Epoch 5: val_loss improved from 0.00196 to 0.00165, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 4.6799e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 6/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.0095e-04
# Epoch 6: val_loss improved from 0.00165 to 0.00164, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - loss: 5.0080e-04 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 7/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.6059e-04
# Epoch 7: val_loss did not improve from 0.00164
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 3.6063e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 8/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.6651e-04
# Epoch 8: val_loss did not improve from 0.00164
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3.6657e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 9/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.8680e-04
# Epoch 9: val_loss did not improve from 0.00164
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 3.8691e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 10/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.2657e-04
# Epoch 10: val_loss did not improve from 0.00164
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 4.2637e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 11/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.2539e-04
# Epoch 11: val_loss improved from 0.00164 to 0.00151, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 3.2529e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 12/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.0511e-04
# Epoch 12: val_loss did not improve from 0.00151
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3.0511e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 13/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.2517e-04
# Epoch 13: val_loss improved from 0.00151 to 0.00148, saving model to best_lstm_model_15.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3.2515e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 14/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.1198e-04
# Epoch 14: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 3.1191e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 15/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.9236e-04
# Epoch 15: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 2.9251e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 16/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.1543e-04
# Epoch 16: val_loss did not improve from 0.00148
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 3.1541e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 17/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.6796e-04
# Epoch 17: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 2.6797e-04 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 18/60
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.8853e-04
# Epoch 18: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 2.8849e-04 - val_loss: 0.0016 - learning_rate: 2.5000e-04
# Epoch 19/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.9668e-04
# Epoch 19: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 2.9655e-04 - val_loss: 0.0021 - learning_rate: 2.5000e-04
# Epoch 20/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.8420e-04
# Epoch 20: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 2.8410e-04 - val_loss: 0.0016 - learning_rate: 2.5000e-04
# Epoch 21/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.6136e-04
# Epoch 21: val_loss did not improve from 0.00148
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - loss: 2.6143e-04 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 22/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.3422e-04
# Epoch 22: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 2.3433e-04 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 23/60
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.6121e-04
# Epoch 23: val_loss did not improve from 0.00148
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - loss: 2.6118e-04 - val_loss: 0.0017 - learning_rate: 1.2500e-04

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step

# %%
# Evaluate model performance
y_test_reshaped = y_test.squeeze()

def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test_reshaped, predictions)
# Out:
# RMSE: 145.68240963325948, MAE: 142.12603188056696, R2: -868608.7646385712

# %%
# Fetch data from Yahoo Finance
aapl = yf.download("AMZN", start="2024-01-01", end="2024-11-30")
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 120
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual Amazon Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted Amazon Prices", color='red')
plt.title("Amazon Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
import pandas as pd
seq_length=120
# Prepare future prediction sequence
X_future = aapl_prices_scaled[-seq_length:].reshape(1, seq_length, 1)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Generate future dates for plotting
# future_dates = pd.date_range(start=datetime.now().strftime('%Y-%m-%d'), periods=11, freq='B')[1:]  # Exclude last known date

# Generate future dates from 14-12-2024 to 24-12-2024
s_date = datetime.now().strftime('%Y-%m-%d')
future_dates = pd.date_range(start=s_date, end="2025-1-3", freq='B')



# Plot the real vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(future_dates, predictions_rescaled.flatten(), label="Predicted Amazon Prices", color='red')  # Predicted
plt.title("Amazon Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
