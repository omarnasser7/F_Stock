# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import joblib

# %%
# Fetch AAPL data from Yahoo Finance for the entire period from 2015 to the present
start_date = '2010-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')

aapl_stock = yf.download('AAPL', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_stock.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.447412  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.458560  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.355826  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.344078  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.386255  7.570714  7.571429  7.466429  7.510714  447610800

# %%
plt.figure(figsize=(12, 6))
plt.plot(aapl_stock['Close'], label='AAPL Close Price')
plt.title('AAPL Stock Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Set Date as index if not already
if 'Date' not in aapl_stock.columns:
    aapl_stock['Date'] = aapl_stock.index
aapl_stock.set_index('Date', inplace=True)

aapl_prices = aapl_stock['Close'].values.reshape(-1, 1)

# Scale data
scaler = MinMaxScaler()
aapl_prices_scaled = scaler.fit_transform(aapl_prices)
joblib.dump(scaler, "appl_scaler.joblib")  # Save the fitted scaler


# Split data into training and testing sets (80% train, 20% test)
train_size = int(len(aapl_prices_scaled) * 0.8)
train_data = aapl_prices_scaled[:train_size]
test_data = aapl_prices_scaled[train_size:]

# Create sequences for LSTM model
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        labels.append(data[i + seq_length])
    return np.array(sequences), np.array(labels)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\omar\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping to prevent overfitting and stop training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,           # Number of epochs with no improvement before stopping
    restore_best_weights=True  # Restore the best weights after stopping
)

# Model checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # Filepath to save the model
    monitor='val_loss',            # Monitor validation loss
    save_best_only=True,           # Save only when the model is the best
    verbose=1                      # Print saving info
)

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',            # Monitor validation loss
    factor=0.5,                    # Reduce learning rate by a factor of 0.5
    patience=5,                    # Number of epochs with no improvement before reducing
    min_lr=1e-6,                   # Minimum learning rate
    verbose=1                      # Print learning rate reduction info
)

# Combine callbacks into a list
callbacks = [early_stopping, model_checkpoint, reduce_lr]

# %%
history = model.fit(
    X_train, 
    y_train, 
    batch_size=8, 
    epochs=50, 
    validation_data=(X_test, y_test), 
    callbacks=callbacks  # Include callbacks in training
)
# Out:
# Epoch 1/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0055
# Epoch 1: val_loss improved from inf to 0.00114, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - loss: 0.0055 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 2/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2919e-04
# Epoch 2: val_loss improved from 0.00114 to 0.00096, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.2928e-04 - val_loss: 9.6358e-04 - learning_rate: 0.0010
# Epoch 3/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4944e-04
# Epoch 3: val_loss improved from 0.00096 to 0.00089, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.4936e-04 - val_loss: 8.9055e-04 - learning_rate: 0.0010
# Epoch 4/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3329e-04
# Epoch 4: val_loss improved from 0.00089 to 0.00080, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.3322e-04 - val_loss: 7.9586e-04 - learning_rate: 0.0010
# Epoch 5/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1298e-04
# Epoch 5: val_loss improved from 0.00080 to 0.00070, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 1.1297e-04 - val_loss: 7.0202e-04 - learning_rate: 0.0010
# Epoch 6/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1200e-04
# Epoch 6: val_loss improved from 0.00070 to 0.00061, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.1187e-04 - val_loss: 6.1439e-04 - learning_rate: 0.0010
# Epoch 7/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.2598e-05
# Epoch 7: val_loss improved from 0.00061 to 0.00037, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 9.2536e-05 - val_loss: 3.7420e-04 - learning_rate: 0.0010
# Epoch 8/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5700e-05
# Epoch 8: val_loss did not improve from 0.00037
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.5708e-05 - val_loss: 4.6160e-04 - learning_rate: 0.0010
# Epoch 9/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4046e-05
# Epoch 9: val_loss improved from 0.00037 to 0.00030, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.4134e-05 - val_loss: 2.9658e-04 - learning_rate: 0.0010
# Epoch 10/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4217e-05
# Epoch 10: val_loss improved from 0.00030 to 0.00028, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 6.4275e-05 - val_loss: 2.8084e-04 - learning_rate: 0.0010
# Epoch 11/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6538e-05
# Epoch 11: val_loss did not improve from 0.00028
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 8.6450e-05 - val_loss: 2.8891e-04 - learning_rate: 0.0010
# Epoch 12/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.3423e-05
# Epoch 12: val_loss did not improve from 0.00028
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 6.3396e-05 - val_loss: 3.5148e-04 - learning_rate: 0.0010
# Epoch 13/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.9206e-05
# Epoch 13: val_loss improved from 0.00028 to 0.00023, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.9233e-05 - val_loss: 2.2973e-04 - learning_rate: 5.0000e-04
# Epoch 14/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5406e-05
# Epoch 14: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.5376e-05 - val_loss: 2.3763e-04 - learning_rate: 5.0000e-04
# Epoch 15/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5308e-05
# Epoch 15: val_loss did not improve from 0.00023
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 4.5296e-05 - val_loss: 4.2792e-04 - learning_rate: 5.0000e-04
# Epoch 16/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5984e-05
# Epoch 16: val_loss improved from 0.00023 to 0.00019, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.6030e-05 - val_loss: 1.9186e-04 - learning_rate: 5.0000e-04
# Epoch 17/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0670e-05
# Epoch 17: val_loss did not improve from 0.00019
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.0699e-05 - val_loss: 2.2669e-04 - learning_rate: 5.0000e-04
# Epoch 18/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5800e-05
# Epoch 18: val_loss did not improve from 0.00019
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.5805e-05 - val_loss: 1.9345e-04 - learning_rate: 5.0000e-04
# Epoch 19/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4914e-05
# Epoch 19: val_loss improved from 0.00019 to 0.00017, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.4904e-05 - val_loss: 1.7294e-04 - learning_rate: 2.5000e-04
# Epoch 20/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.6350e-05
# Epoch 20: val_loss did not improve from 0.00017
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.6332e-05 - val_loss: 1.7736e-04 - learning_rate: 2.5000e-04
# Epoch 21/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.6209e-05
# Epoch 21: val_loss did not improve from 0.00017
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.6173e-05 - val_loss: 1.7956e-04 - learning_rate: 2.5000e-04
# Epoch 22/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0747e-05
# Epoch 22: val_loss did not improve from 0.00017
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 3.0749e-05 - val_loss: 2.6702e-04 - learning_rate: 2.5000e-04
# Epoch 23/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2982e-05
# Epoch 23: val_loss did not improve from 0.00017
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 3.2968e-05 - val_loss: 2.3940e-04 - learning_rate: 2.5000e-04
# Epoch 24/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4580e-05
# Epoch 24: val_loss improved from 0.00017 to 0.00017, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.4599e-05 - val_loss: 1.6825e-04 - learning_rate: 1.2500e-04
# Epoch 25/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4709e-05
# Epoch 25: val_loss did not improve from 0.00017
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.4714e-05 - val_loss: 1.8712e-04 - learning_rate: 1.2500e-04
# Epoch 26/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.9783e-05
# Epoch 26: val_loss improved from 0.00017 to 0.00017, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.9776e-05 - val_loss: 1.6514e-04 - learning_rate: 1.2500e-04
# Epoch 27/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4586e-05
# Epoch 27: val_loss improved from 0.00017 to 0.00016, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.4586e-05 - val_loss: 1.6133e-04 - learning_rate: 1.2500e-04
# Epoch 28/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5227e-05
# Epoch 28: val_loss improved from 0.00016 to 0.00016, saving model to best_lstm_model.keras
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.5232e-05 - val_loss: 1.5876e-04 - learning_rate: 1.2500e-04
# Epoch 29/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5392e-05
# Epoch 29: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 2.5386e-05 - val_loss: 1.5991e-04 - learning_rate: 6.2500e-05
# Epoch 30/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2874e-05
# Epoch 30: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.2875e-05 - val_loss: 2.0128e-04 - learning_rate: 6.2500e-05
# Epoch 31/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2328e-05
# Epoch 31: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.2338e-05 - val_loss: 1.9214e-04 - learning_rate: 6.2500e-05
# Epoch 32/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1019e-05
# Epoch 32: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1031e-05 - val_loss: 1.7060e-04 - learning_rate: 6.2500e-05
# Epoch 33/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4035e-05
# Epoch 33: val_loss did not improve from 0.00016
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.4035e-05 - val_loss: 1.5953e-04 - learning_rate: 6.2500e-05
# Epoch 34/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3048e-05
# Epoch 34: val_loss improved from 0.00016 to 0.00016, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.3039e-05 - val_loss: 1.5722e-04 - learning_rate: 3.1250e-05
# Epoch 35/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1324e-05
# Epoch 35: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1327e-05 - val_loss: 1.6459e-04 - learning_rate: 3.1250e-05
# Epoch 36/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0408e-05
# Epoch 36: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 2.0422e-05 - val_loss: 1.6296e-04 - learning_rate: 3.1250e-05
# Epoch 37/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2328e-05
# Epoch 37: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.2328e-05 - val_loss: 1.5913e-04 - learning_rate: 3.1250e-05
# Epoch 38/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1139e-05
# Epoch 38: val_loss did not improve from 0.00016
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1141e-05 - val_loss: 1.9142e-04 - learning_rate: 3.1250e-05
# Epoch 39/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0429e-05
# Epoch 39: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.0439e-05 - val_loss: 1.7128e-04 - learning_rate: 1.5625e-05
# Epoch 40/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2534e-05
# Epoch 40: val_loss improved from 0.00016 to 0.00016, saving model to best_lstm_model.keras
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.2531e-05 - val_loss: 1.5592e-04 - learning_rate: 1.5625e-05
# Epoch 41/50
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1261e-05
# Epoch 41: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1261e-05 - val_loss: 1.6300e-04 - learning_rate: 1.5625e-05
# Epoch 42/50
# 366/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1555e-05
# Epoch 42: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1553e-05 - val_loss: 1.7759e-04 - learning_rate: 1.5625e-05
# Epoch 43/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2368e-05
# Epoch 43: val_loss did not improve from 0.00016
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.2363e-05 - val_loss: 1.5678e-04 - learning_rate: 1.5625e-05
# Epoch 44/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8144e-05
# Epoch 44: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.8169e-05 - val_loss: 1.7156e-04 - learning_rate: 7.8125e-06
# Epoch 45/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1096e-05
# Epoch 45: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.1096e-05 - val_loss: 1.6119e-04 - learning_rate: 7.8125e-06
# Epoch 46/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5636e-05
# Epoch 46: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.5611e-05 - val_loss: 1.5944e-04 - learning_rate: 7.8125e-06
# Epoch 47/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9759e-05
# Epoch 47: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.9768e-05 - val_loss: 1.6164e-04 - learning_rate: 7.8125e-06
# Epoch 48/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3802e-05
# Epoch 48: val_loss did not improve from 0.00016
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.3788e-05 - val_loss: 1.5745e-04 - learning_rate: 7.8125e-06
# Epoch 49/50
# 367/369 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2153e-05
# Epoch 49: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 2.2142e-05 - val_loss: 1.6257e-04 - learning_rate: 3.9063e-06
# Epoch 50/50
# 368/369 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2168e-05
# Epoch 50: val_loss did not improve from 0.00016
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 2.2161e-05 - val_loss: 1.6220e-04 - learning_rate: 3.9063e-06

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(aapl_stock.index[train_size:], aapl_stock['Close'][train_size:], label='Actual AAPL Stock Price')
plt.plot(aapl_stock.index[train_size + seq_length:], predictions, label='Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"RMSE: {rmse}, MAE: {mae}, R2: {r2}")

evaluate_model(y_test, predictions)
# Out:
# RMSE: 178.84387255701301, MAE: 176.7303799915169, R2: -2316941.1086291564

# %%
# Fetch data from Yahoo Finance
aapl = yf.download("AAPL", start="2024-01-01", end="2024-11-30")
aapl['Date'] = aapl.index
aapl_prices = aapl['Close'].values.reshape(-1, 1)

# Scale the data using the same scaler
# scaler = MinMaxScaler()
aapl_prices_scaled = scaler.transform(aapl_prices)

# Create sequences for prediction
seq_length = 60
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

X_future = create_sequences(aapl_prices_scaled, seq_length)

# Predict November 2024 stock prices
predictions = model.predict(X_future)
predictions_rescaled = scaler.inverse_transform(predictions)

# Plot real vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(aapl['Date'], aapl['Close'], label="Actual AAPL Prices", color='blue')
plt.plot(aapl['Date'][seq_length:], predictions_rescaled, label="Predicted AAPL Prices", color='red')
plt.title("AAPL Stock Price Prediction for November 2024")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
